# %% [markdown]
# # API-201 ABC PROBLEM SET #10
# **Due on Wednesday, November 16, at 11:59 p.m.**

# %% [markdown]
# **I - INSTRUCTIONS**
# To successfully complete this problem set, please follow these steps:
#
# 1. **Create a copy of this Jupyter notebook in your own drive by clicking `Copy to Drive` in the menubar (this is explained below in more detail below) - *if you do not do this your work will not be saved!***
#     1. Remember to save your work frequently by pressing `command-S` or clicking `File > Save` in the menubar.
#     1. We recommend completing this problem set in Google Chrome.
# 2. **Insert all your answers into your copy of the document.**
#     1. Please include every portion of your submission in this document unless a separate electronic file is explicitly requested.
#     3. All numerical calculations should be done in the notebook itself, using R code. If you have to do calculations by hand, include a picture of your handwritten work.
#     2. To add an image of handwritten work, screenshots, or anything else, add a new text cell and click the small image icon in the menubar above the cell. After inserting an image, press the `esc` key to show the image. If you have trouble with this method, upload your image to [Freeimage.host](https://freeimage.host), copy a Markdown link, and paste it in a text cell.
# 3. **Once your document is complete, please save and submit the notebook on Canvas as a PDF.**
#     1. Click `View > Expand sections` in the menubar to make sure all work is visible (if it is greyed out then it is already visible).
#     1. Click `Runtime > Run all` in the menubar to make sure all of your code is executed.
#     1. Click `File > Print` in the menubar and choose the `Save as PDF` option in Chrome to export your notebook as a PDF.
#     1. Check to make sure answers do not get cut off - when you go to print the PDF we recommend clicking on `More settings` and setting `Margins` to `None`.
#     1. Submit your file on Canvas.

# %% [markdown]
# **II - IDENTIFICATION**
# 1. **Your Full Name:** `     `
#
# 2. **Group Members (classmates with whom you worked on this problem set):**
#     1. `     `
#     2. `     `
#     3. `     `
#     4. `     `
#
# 3. **Compliance with HKS Academic Code**
# We abide by the Harvard Kennedy School Academic code for all aspects of the course. In terms of problem sets, unless explicitly written otherwise, the norms are the following: You are free (and encouraged) to discuss problem sets with your classmates. However, you must hand in your own unique written work and code in all cases. Any copy/paste of another’s work is plagiarism. In other words, you may work with your classmate(s), sitting side-by-side (physically or remotely!) and going through the problem set question by question, but you must each type your own answers and your own code. For more details, please see syllabus.
#
#     **I certify that my work in this problem set complies with the HKS Academic Code**
#     - [ ] Yes
#     - [ ] No
#
# ---

# %% [markdown]
# **Note: This week's content focuses entirely on qualitative methods and their applications to policy. As such, there are no coding or quantitative components to this problem set. Instead, we ask that you do a sequence of readings that will inform our class on Thursday. In addition to answering the questions below, we highly recommend that you take notes on the readings that you bring to class with you, as we may ask you to explain key concepts to one another in class.**

# %% [markdown]
# # PART I – ASSESSING QUALITATIVE RESEARCH

# %% [markdown]
# Throughout this course, we have worked to develop the ability to assess the quality of quantitative research in various contexts, including descriptive evidence (Classes 2 and 3), assessing probabilistic claims (Class 11), and statistical inference (Class 18-20). By now you should have a sense of what to look out for when reading an analysis or assessing a claim.
#
# **a. Referring to our discussions from prior classes, describe three criteria that you will use to assess the quality of a quantitative analysis that you encounter. For each, briefly articulate why that criterion is so important.**

# %% [markdown]
# Your criteria here!
#
# 1. Criterion #1:
#     - Why it is important:
# 2. Criterion #2:
#     - Why it is important:
# 3. Criterion #3:
#     - Why it is important:

# %% [markdown]
# We will spend next week discussing qualitative research, which often has a different set of goals and criteria against which it should be evaluated. One set of criteria is proposed by Mario Luis Small and Jessica McCrory Calarco in the book "***Qualitative Literacy***" (linked on the Canvas homepage).
#
# Begin by reading the introduction of the book (pages 1-22), which lays out the challenge of evaluating qualitative research effectively.
#
# **b. Briefly summarize the five criteria that the authors propose.**

# %% [markdown]
# Your answer here!

# %% [markdown]
# Net, reflect on the similarities and differences between the criteria you describe in part (a) and those in part (b).
#
# **c. What similarities do you see between the criteria? Do you believe that qualitative research should be assessed using any of the quantitative criteria? Are there qualitative criteria that should be used to assess quantitative research? \[1-2 paragraphs\]**

# %% [markdown]
# Your answer here!

# %% [markdown]
# **d. How are the criteria different, and what do the differences between them tell you about the aims of quantitative and qualitative research? \[1 paragraph\]**

# %% [markdown]
# Your answer here!

# %% [markdown]
# The book is divided into five remaining chapters, one for each criterion. Depending on the first letter of your last name, read one of the chapters:
#
# 1. \[A-E\]: Cognitive empathy
# 2. \[F-J\]: Heterogeneity
# 3. \[K-O\]: Palpability
# 4. \[P-T\]: Follow-up
# 5. \[U-Z\]: Self-awareness
#
# *Note: If you have a strong preference to read about one of the criteria, you can do that instead of adhering to these divisions!*

# %% [markdown]
# **e. Briefly describe the criterion you read about. Then, consider that criterion in the context of crafting and implementing effective policy. What is your assessment of the importance of that criterion when assessing qualitative research in that context? Imagine that you are crafting a policy response; what is an example of a pitfall that could arise if the research used to inform the policy did not meet your criterion?**

# %% [markdown]
# Your answer here!

# %% [markdown]
# # PART II – PCE: REVISITING MEDICAID

# %% [markdown]
# For Thursday's class, we would like you to revisit the takeaways of the Oregon Health Insurance Experiment that we studied last week. To do so, please read the following paper (available [here](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6707030/)):
#
# > Saluja S, McCormick D, Cousineau MR, Morrison J, Shue L, Joyner K, Hochman M. Barriers to Primary Care After the Affordable Care Act: A Qualitative Study of Los Angeles Safety-Net Patients' Experiences. Health Equity. 2019 Aug 23;3(1):423-430.
#
# **IMPORTANT NOTE:  This article will serve as the basis for discussion on Thursday’s class.**
#
# After reading this article, answer the following questions. Please bring your answers with you to class!

# %% [markdown]
# **a. In 1-2 paragraphs, synthesize this article and the Oregon study from last week. What insights does this article provide that was not present in the Oregon study? Does it change your interpretation of the Oregon study's results? Why or why not?**

# %% [markdown]
# Your answer here!

# %% [markdown]
# **b. In 1-2 paragraphs, assess the quality of the study you just read using the criterion that you read about from *Qualitative Literacy*.**
#
# *Note that these criteria were developed for more immersive, in-depth studies than the one you read. Still, it is a useful exercise to assess the article's strengths from the perspective of these criteria.*

# %% [markdown]
# Your answer here!

# %% [markdown]
# **c. Describe a potential qualitative research study that you would be interested in reading to further deepen your understanding of the effectiveness of Medicaid. What methods would you use, and what population would you target?**

# %% [markdown]
# Your answer here!

# %% [markdown]
# Finally, please paste your answers from this part to the pre-class exercise for Thursday's class:
#
# - [Section A (Prof. Borck)](https://canvas.harvard.edu/courses/109219/modules/231169)
# - [Section B (Prof. Svoronos)](https://canvas.harvard.edu/courses/109220/modules/231164)
# - [Section C (Prof. Goel)](https://canvas.harvard.edu/courses/109221/modules/231147)
#
# **Completed the module**
# - [ ] Yes
# - [ ] No

# %% [markdown]
# # PART III: FRIDAY'S QUALITATIVE METHODS PANEL

# %% [markdown]
# This Friday, November 18 from 12:00 - 1:15, we will be hosting a virtual panel of three HKS faculty members who engage heavily in qualitative research (this is in lieu of a TF session). You should plan to attend this session **[live over Zoom](https://harvard.zoom.us/j/97695424789?pwd=QWxRUmYxTG1KQkdpUENqZWhzOURvZz09)** - in addition to the panel discussion, you will have an opportunity to talk to individual faculty members in breakout rooms.
#
# **You can find details on the three panelists [here](https://docs.google.com/document/d/1CJl_vsDGyr2dhifs-2ddbNzqbeiHQ_Qk3o5yiLp4cWE/).**
#
# After browsing their bios and work, please use the link below to pose questions to the panelists and vote on one another's questions. The interface will ask you to choose between two questions at a time - feel free to go through as many as you would like. We will use your questions to guide our discussion on Friday!
#
# **[Click here to pose a question](http://www.allourideas.org/201qual)**
#
# **I have asked a question and/or voted on other questions for Friday's panel**
# - [ ] Yes
# - [ ] No
