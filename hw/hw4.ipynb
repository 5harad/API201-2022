# %% [markdown]
# # API-201 ABC PROBLEM SET #4
# **Due on Wednesday, September 28, at 11:59 p.m.**

# %% [markdown]
# **I - INSTRUCTIONS**
# To successfully complete this problem set, please follow these steps:
#
# 1. **Create a copy of this Jupyter notebook in your own drive by clicking `Copy to Drive` in the menubar (this is explained below in more detail below) - *if you do not do this your work will not be saved!***
#     1. Remember to save your work frequently by pressing `command-S` or clicking `File > Save` in the menubar.
#     1. We recommend completing this problem set in Google Chrome.
# 2. **Insert all your answers into your copy of the document.**
#     1. Please include every portion of your submission in this document unless a separate electronic file is explicitly requested.
#     3. All numerical calculations should be done in the notebook itself, using R code. If you have to do calculations by hand, include a picture of your handwritten work.
#     2. To add an image of handwritten work, screenshots, or anything else, add a new text cell and click the small image icon in the menubar above the cell. After inserting an image, press the `esc` key to show the image. If you have trouble with this method, upload your image to [Freeimage.host](https://freeimage.host), copy a Markdown link, and paste it in a text cell.
# 3. **Once your document is complete, please save and submit the notebook on Canvas as a PDF.**
#     1. Click `View > Expand sections` in the menubar to make sure all work is visible (if it is greyed out then it is already visible).
#     1. Click `Runtime > Run all` in the menubar to make sure all of your code is executed.
#     1. Click `File > Print` in the menubar and choose the `Save as PDF` option in Chrome to export your notebook as a PDF.
#     1. Check to make sure answers do not get cut off - when you go to print the PDF we recommend clicking on `More settings` and setting `Margins` to `None`.
#     1. Submit your file on Canvas.

# %% [markdown]
# **II - IDENTIFICATION**
# 1. **Your Full Name:** `     `
#
# 2. **Group Members (classmates with whom you worked on this problem set):**
#     1. `     `
#     2. `     `
#     3. `     `
#     4. `     `
#
# 3. **Compliance with HKS Academic Code**
# We abide by the Harvard Kennedy School Academic code for all aspects of the course. In terms of problem sets, unless explicitly written otherwise, the norms are the following: You are free (and encouraged) to discuss problem sets with your classmates. However, you must hand in your own unique written work and code in all cases. Any copy/paste of another’s work is plagiarism. In other words, you may work with your classmate(s), sitting side-by-side (physically or remotely!) and going through the problem set question by question, but you must each type your own answers and your own code. For more details, please see syllabus.
#
#     **I certify that my work in this problem set complies with the HKS Academic Code**
#     - [ ] Yes
#     - [ ] No
#
# ---

# %% [markdown]
# ## Load `R` libraries and data
#
# **Kendrick McDonald from the API-201 Teaching Team has put together this [R Cheat Sheet](https://docs.google.com/spreadsheets/d/1qNGOm4xKvL6d5u_OHUM27aP0dq3BUsfJ-ddPrs_MVzI/edit#gid=0) with key commands (in Sheet 1) and troubleshooting steps if you encounter an error (in Sheet 2). We will continue to build this out over the course of the semester.**
#
# The code cell below imports the R tidyverse and creates a dataframe that we will be using for Part III. Make sure to run it before starting the problem set!
#
# *Note: Click the "play" button that appears when you hover over a cell to run it. The first time you do this you may receive an alert that this notebook was not authored by Google. If so, click "Run anyway" to proceed.*

# %%
library(tidyverse)

# Create a data frame for Part III
senate_prediction <- tibble(
    Rseats = 57:43, 
    Dseats = 43:57, 
    Prob = c(0.002, 0.004, 0.011, 0.025, 0.049, 0.078, 0.114, 0.145, 0.155, 0.152, 0.118, 0.083, 0.043, 0.016, 0.004)
    )

# %% [markdown]
# -----
#
# # PART 0: QUARTER-COURSE FEEDBACK
#
# > Now that we have settled into a rhythm in API-201, we would like to get a sense from you about how the course is going from your perspective.  Please complete this brief survey to give us your feedback. Your answers are anonymous and we would like to encourage you to be both candid and constructive. Our goal is to be able to use your feedback to improve the course. We estimate it will take you about 10 minutes to fill it in. Thank you in advance for your feedback!
# >
# > – Profs. Jonathan Borck, Sharad Goel, and Teddy Svoronos
#
# **[Click here to complete our mid-course feedback survey.](https://harvard.az1.qualtrics.com/jfe/form/SV_cvxovQZmShJjcmq)**
#
# **Completed the survey**
# - [ ] Yes
# - [ ] No

# %% [markdown]
# # PART I: RACE AND ECONOMIC OPPORTUNITY
#
# A research team at [Opportunity Insights](https://opportunityinsights.org/paper/race/) recently released a study titled “Race and Economic Opportunity in the United States: An Intergenerational Perspective.”  Building on the approach we discussed in class, the authors examined intergenerational mobility by race in the United States.  Here is a subset of their findings for (a) Hispanic children; (b) Black, non-Hispanic children; and (c) American Indian and Alaskan native children.
#
# Note: For this question, you can assume that quintiles are defined separately for each racial group - that is to say, we know that exactly 1/5 of that group lies in each quintile.

# %% [markdown]
# *Panel A: Hispanic children*
#
# <table>
#     <tbody>
#         <tr>
#             <td></td>
#             <td colspan="5">
#                 <strong>Child&rsquo;s Household Income Quintile as an Adult</strong>
#                 <strong>(1 = Poorest)</strong>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Parental Income Quintile</strong>
#                 <strong>(1 = Poorest)</strong>
#             </td>
#             <td>
#                 1
#             </td>
#             <td>
#                 2
#             </td>
#             <td>
#                 3
#             </td>
#             <td>
#                 4
#             </td>
#             <td>
#                 5
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 1
#             </td>
#             <td>
#                 0.248
#             </td>
#             <td>
#                 0.299
#             </td>
#             <td>
#                 0.237
#             </td>
#             <td>
#                 0.146
#             </td>
#             <td>
#                 0.071
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 2
#             </td>
#             <td>
#                 0.198
#             </td>
#             <td>
#                 0.263
#             </td>
#             <td>
#                 0.257
#             </td>
#             <td>
#                 0.182
#             </td>
#             <td>
#                 0.099
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 3
#             </td>
#             <td>
#                 0.170
#             </td>
#             <td>
#                 0.223
#             </td>
#             <td>
#                 0.256
#             </td>
#             <td>
#                 0.212
#             </td>
#             <td>
#                 0.140
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 4
#             </td>
#             <td>
#                 0.146
#             </td>
#             <td>
#                 0.187
#             </td>
#             <td>
#                 0.240
#             </td>
#             <td>
#                 0.233
#             </td>
#             <td>
#                 0.195
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 5
#             </td>
#             <td>
#                 0.120
#             </td>
#             <td>
#                 0.140
#             </td>
#             <td>
#                 0.199
#             </td>
#             <td>
#                 0.235
#             </td>
#             <td>
#                 0.306
#             </td>
#         </tr>
#     </tbody>
# </table>
# <br>
#
# *Panel B: Black, non-Hispanic children*
#
# <table>
#     <tbody>
#         <tr>
#             <td></td>
#             <td colspan="5">
#                 <strong>Child&rsquo;s Household Income Quintile as an Adult</strong>
#                 <strong>(1 = Poorest)</strong>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Parental Income Quintile</strong>
#                 <strong>(1 = Poorest)</strong>
#             </td>
#             <td>
#                 1
#             </td>
#             <td>
#                 2
#             </td>
#             <td>
#                 3
#             </td>
#             <td>
#                 4
#             </td>
#             <td>
#                 5
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 1
#             </td>
#             <td>
#                 0.373
#             </td>
#             <td>
#                 0.380
#             </td>
#             <td>
#                 0.158
#             </td>
#             <td>
#                 0.063
#             </td>
#             <td>
#                 0.025
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 2
#             </td>
#             <td>
#                 0.301
#             </td>
#             <td>
#                 0.359
#             </td>
#             <td>
#                 0.204
#             </td>
#             <td>
#                 0.093
#             </td>
#             <td>
#                 0.043
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 3
#             </td>
#             <td>
#                 0.253
#             </td>
#             <td>
#                 0.316
#             </td>
#             <td>
#                 0.233
#             </td>
#             <td>
#                 0.129
#             </td>
#             <td>
#                 0.069
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 4
#             </td>
#             <td>
#                 0.210
#             </td>
#             <td>
#                 0.278
#             </td>
#             <td>
#                 0.247
#             </td>
#             <td>
#                 0.162
#             </td>
#             <td>
#                 0.102
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 5
#             </td>
#             <td>
#                 0.167
#             </td>
#             <td>
#                 0.214
#             </td>
#             <td>
#                 0.239
#             </td>
#             <td>
#                 0.201
#             </td>
#             <td>
#                 0.180
#             </td>
#         </tr>
#     </tbody>
# </table>
# <br>
#
#
# *Panel C: American Indian and Alaskan Native children*
#
# <table>
#     <tbody>
#         <tr>
#             <td></td>
#             <td colspan="5">
#                 <strong>Child&rsquo;s Household Income Quintile as an Adult</strong>
#                 <strong>(1 = Poorest)</strong>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <strong>Parental Income Quintile</strong>
#                 <strong>(1 = Poorest)</strong>
#             </td>
#             <td>
#                 1
#             </td>
#             <td>
#                 2
#             </td>
#             <td>
#                 3
#             </td>
#             <td>
#                 4
#             </td>
#             <td>
#                 5
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 1
#             </td>
#             <td>
#                 0.455
#             </td>
#             <td>
#                 0.276
#             </td>
#             <td>
#                 0.155
#             </td>
#             <td>
#                 0.081
#             </td>
#             <td>
#                 0.033
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 2
#             </td>
#             <td>
#                 0.359
#             </td>
#             <td>
#                 0.273
#             </td>
#             <td>
#                 0.194
#             </td>
#             <td>
#                 0.118
#             </td>
#             <td>
#                 0.056
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 3
#             </td>
#             <td>
#                 0.284
#             </td>
#             <td>
#                 0.248
#             </td>
#             <td>
#                 0.214
#             </td>
#             <td>
#                 0.163
#             </td>
#             <td>
#                 0.091
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 4
#             </td>
#             <td>
#                 0.229
#             </td>
#             <td>
#                 0.212
#             </td>
#             <td>
#                 0.220
#             </td>
#             <td>
#                 0.202
#             </td>
#             <td>
#                 0.137
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 5
#             </td>
#             <td>
#                 0.188
#             </td>
#             <td>
#                 0.169
#             </td>
#             <td>
#                 0.198
#             </td>
#             <td>
#                 0.215
#             </td>
#             <td>
#                 0.230
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# **a. Are the distributions in the tables above joint distributions, conditional distributions, or something else?  How do you know?**

# %% [markdown]
# Your answer here!

# %% [markdown]
# **b. Calculate the probability that a Hispanic child ends up in a higher income quintile than their parents.  Explain your calculation and (as always!) show your work.**
#
# *Note: If you use R as a calculator, add a code cell below with your calculations*

# %% [markdown]
# Your answer here!

# %% [markdown]
# Your friend, who took API-201 last year, makes the following observation:
#
# > “Based on the tables above, Hispanic children, Black, non-Hispanic children, and American Indian and Alaskan natives appear similar with respect to intergenerational mobility.  And kids from all three groups who grew up poor do not appear to be moving up in the income distribution across generations (i.e., relative to their parents).”
#
# **c. Assess your friend’s claim using the information in the tables above.  [1-2 paragraphs]**

# %% [markdown]
# Your answer here!

# %% [markdown]
# One of the [study’s findings](https://opportunityinsights.org/wp-content/uploads/2018/04/race_summary.pdf) is that “The black-white income gap is entirely driven by differences in men’s, not women’s, outcomes.”  In a writeup of the authors’ findings, the New York Times created a dramatic visual of how Black boys and white boys born to parents in the top (richest) income quintile fared later in life.  Please watch the data visualization [located here](https://www.nytimes.com/interactive/2018/03/19/upshot/race-class-white-and-black-men.html). The visualization is embedded in the article and looks like this at the start:

# %% [markdown]
# ![Visualization](data:image/png;base64,...)

# %% [markdown]
# After watching the data visualization to the end, please assess the following claims based on the results.

# %% [markdown]
# **d. True, False, or Uncertain?  “Black men who grew up rich are twice as likely as white men who grew up rich to be poor adults.”  Explain your answer.**

# %% [markdown]
# Check one:
# - [ ] True
# - [ ] False
# - [ ] Uncertain
#
# Your explanation here!

# %% [markdown]
# **e. True, False, or Uncertain?  “A majority of middle-class adults are Black men.”  Explain your answer.**

# %% [markdown]
# Check one:
# - [ ] True
# - [ ] False
# - [ ] Uncertain
#
# Your explanation here!

# %% [markdown]
# # PART II: HOW TO TALK ABOUT FLOODS
#
# Recent hurricanes (including Hurricanes Dorian, Harvey, Irma, Maria, Florence, and Ida) have caused flooding, damage, and substantial loss of life in various areas of the United States and the Caribbean. This question focuses on one effect of hurricanes: flooding.
#
# Experts and commentators often use terms such as “50-year flood,” “100-year flood,” and “500-year flood” to describe the likely frequency of flooding due to storms such as the recent hurricanes.  According to experts such as the United States Geological Survey, a “100-year flood” is a flood that has a 1 percent chance of happening in each year - similarly, a 50-year flood is a flood that has a 2 percent chance of happening each year (Note that as a simplifying assumption, we are assuming that we can't have more than one flood per year).
#
# The general public does not often interpret the terms in this way - specifically, it often does not understand that a 100-year flood can happen more than once per 100 years.
#
# As background for this question, please [read this op-ed](https://drive.google.com/file/d/131Ti68YnkWXpOdZa15lYeSb45k-8wQFA/view?usp=sharing).

# %% [markdown]
# ### 1. Talking about floods

# %% [markdown]
# **a. Explain how it's possible to have a 100-year flood more than once per 100 years.**

# %% [markdown]
# Your answer here!

# %% [markdown]
# Brian Bledsoe, the author of the linked essay and a professor at the University of Georgia, writes:
#
# > "\[M\]ost people are still surprised, if not astonished, to learn that the 100-year flood at a given location has more than a 1 in 4 chance of occurring within the term of a 30-year mortgage. For most of us, this 26 percent chance our home will be flooded before we have a chance to pay it off is troubling if not unacceptable."
#
# **b. Show how Professor Bledsoe got to this probability (26 percent). Is his calculation correct?**

# %% [markdown]
# Your answer here!

# %% [markdown]
# **c. In one crisp paragraph, explain to a policymaker who is curious but not well versed in probability and statistics how a 100-year flood actually has more than a one-in-four chance of occurring over a 30-year period.**

# %% [markdown]
# Your answer here!

# %% [markdown]
# Finally, Professor Bledsoe makes a proposal to change the way communication about natural hazards is done.
#
# **d. In one crisp paragraph, explain whether you think this proposal would improve people’s understanding of the risks posed by natural hazards. If so, explain why. If not, explain why not and suggest a better proposal.**

# %% [markdown]
# Your answer here!

# %% [markdown]
# ### 2. Simulating floods

# %% [markdown]
# One way in which R can help us gain an intuitive feel for probabilities is through simulation.  In general, simulation is an analytical methodology that allows us to “simulate” how the world might evolve in the presence of uncertainty.  Simulations are typically run hundreds if not thousands of times.  We can then examine the results, individually and in the aggregate over the runs of the simulation, to better understand the role that uncertainty plays in the outcomes.

# %% [markdown]
# **a. Let’s simulate the possibility of flooding in a particular area.**

# %% [markdown]
# *i. Let’s first focus on developing a line of code that will provide us with the number of floods one would expect in 30 years, if there is a 1% chance of a flood each year (and again, assuming that we cannot have more than one flood per year).*
#
# *In one line, use the `rbernoulli` function to generate 30 `TRUE` or `FALSE` outcomes, one for each year, and sum them together to see how many floods you would see. We provide a few objects to get you started (Note: refer to last problem set to remind yourself how the `rbernoulli` function works).*
#
# *Every time you run the line of code that you produce, you're simulating a 30 year period and showing how many floods one might see. If you run it many times, you'll see the number of floods fluctuate due to chance.*

# %%
years <- 30
p_flood <- 0.01

# Your answer here!

# %% [markdown]
# *ii. Instead of manually running the line of code that you produced 1000 times, let's use the `replicate` function to do so.*
#
# *The replicate command is of the form `replicate(number of simulations, code to run each simulation)`. Using the line of code you produced in the prior question and the `num_sims` object below, create a line of code that simulates how many floods we would see in 30 years 1,000 times. Your output should be 1,000 numbers, each corresponding to the number of floods in that particular simulation. Name this object of simulations `sims`.*
#
# *Note: copy and paste the entire line of code from the previous question (i.e., if you created an object corresponding to one sim in the previous question, don't just reference that object). `replicate` needs to actually run the code each time! Also, we use the `set.seed(1)` command to make sure that R produces the sames set of results each time we run the command.*

# %%
set.seed(1)
num_sims <- 1000

# Your answer here!

# %% [markdown]
# **b. What is the average number of floods in a 30 year period from your 1000 simulations?**

# %%
# Your answer here!

# %% [markdown]
# **c. Generate a histogram of the number of floods over 30 years based on your simulation.  Specifically, your histogram should show the number of simulation runs (out of 1000) in which there were zero floods, one flood, two floods, etc.**
#
# *Hint: `ggplot` requires that you provide a dataset, and the simulations you produced above is just a vector of numbers. You can use the line of code below to turn your object `sims` into a dataset called `flood_simulation` with variable `n_floods` corresponding to the number of floods in each simulation.*

# %%
flood_simulation <- tibble(n_floods = sims)

# Your answer here!

# %% [markdown]
# **d. In how many simulation runs were there at least one flood in 30 years?  Do your results support Professor Bledsoe’s calculation and your own calculation in Question 1b?**

# %%
# Your answer here!

# %% [markdown]
# # PART III: U.S. SENATE FORECAST
#
# In this November’s U.S. election, voters in 34 U.S. states will select a total of 35 Senators.  The U.S. Senate has 100 members (many of whom are not up for re-election this year), and control of the U.S. Senate will depend on the outcomes of these 35 elections.
#
# The forecasting website FiveThirtyEight has developed a model of these elections and the likelihoods of various aggregate outcomes. [FiveThirtyEight’s forecast](https://projects.fivethirtyeight.com/2022-election-forecast/senate/) as of September 16, 2022, appears below.  If members of one party — either the Democrats (represented in blue) or the Republicans (in red) — win 51 seats in total, that party will control the Senate.  If the election results in each party holding 50 seats, the Democrats will control the Senate due to the tie-breaking vote of U.S. Vice President Kamala Harris.

# %% [markdown]
# ![FiveThirtyEight Forecast.png](data:image/png;base64,...)

# %% [markdown]
# The "setup" cell at the start of the problem set also creates a data frame containing the values in the figure above, called `senate_prediction`. This may come in handy for the questions below!

# %%
senate_prediction

# %% [markdown]
# **a. According to the FiveThirtyEight forecast, what is the single most likely outcome for the makeup of the U.S. Senate after the November elections? Do you consider this likelihood "high"? Briefly explain.**

# %% [markdown]
# Your answer here!

# %% [markdown]
# **b. According to the FiveThirtyEight forecast, what is the probability that the Republican Party maintains a majority of seats in the U.S. Senate (i.e., 51 seats or more)?  As always, please show your work.**

# %%
# Calculations here!

# %% [markdown]
# Your answer here!

# %% [markdown]
# **c. Calculate the expected number of seats held by Democrats after the November elections based on the FiveThirtyEight forecast.  As always, please show your work.**

# %%
# Calculations here!

# %% [markdown]
# Your answer here!

# %% [markdown]
# # PART IV: PCE ON DECISION ANALYSIS
#
# The goal of this question is to help you prepare for Class #9, so we can use our time in the classroom most productively. You are asked to engage in an online module to learn the basics of decision analysis and decision trees. We estimate that the time to engage with this online module is about 30-45 minutes.
#
# Throughout the module you will be asked some questions. We will look at the overall performance of the class to target the class better to your learning needs, but your individual performance on these questions will not count towards your grade. You will get full credit for answering the questions, independently of whether your answers are correct.
#
# **Important Note: This is a full online module with videos and practice problems, not just a quiz.  Your “To Do” list in Canvas will send you directly to the quiz without showing you the module, so please use the link on the Canvas homepage or below to access the module instead.**
#
# __The module is available at the following sites:__
#
# - [Section A (Prof. Borck)](https://canvas.harvard.edu/courses/109219/modules/228853)
# - [Section B (Prof. Svoronos)](https://canvas.harvard.edu/courses/109220/modules/228854)
# - [Section C (Prof. Goel)](https://canvas.harvard.edu/courses/109221/modules/228852)

# %% [markdown]
# **Completed the module**
# - [ ] Yes
# - [ ] No
